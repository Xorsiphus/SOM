# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# data = pd.read_json("generated.json")
# data = pd.read_csv("ratings.json")
data = pd.read_csv("anime.csv")

# print(data.info())

# data['genre'].value_counts().plot.pie(autopct='%1.1f%%', figsize=(20, 20))

lines = data['genre'].str.split(', ')
genres = {}
indexes = []

for line in lines:
    if type(line) is list:
        for genre in line:
            if genre not in genres:
                genres[genre] = 0
            else:
                genres[genre] += 1
# print(genres)

genres_data = {'genres': []}
counter = 0
for genre in genres:
    indexes.append(genre)
    genres_data['genres'].append(genres[genre])

# print(indexes)
# print(genres_data)

df = pd.DataFrame(genres_data, index=indexes)
df.plot.pie(autopct='%1.1f%%', figsize=(20, 20), y='genres')
# Out:
# <AxesSubplot:ylabel='genres'>

# %%
# Мат. ожидание
np.nanmean(data['rating'])
# Out:
# 6.473901690981432

# %%
# Дисперсия
np.nanvar(data['rating'])
# Out:
# 1.0541205941151777

# %%
# Среднеквадратичное отклонение
np.nanstd(data['rating'])
# Out:
# 1.0267037518754754

# %%
# Медиана
np.nanmedian(data['rating'])
# Out:
# 6.57

# %%
plt.figure(figsize=(15, 10))
sns.histplot(data['rating'])
# Out:
# <AxesSubplot:xlabel='rating', ylabel='Count'>

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(y=data['rating'])
# Out:
# <AxesSubplot:ylabel='rating'>
